# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Leer el archivo de Excel
lista = pd.read_excel('/content/sample_data/Watec_Clasificados_DataClasificadosyNoClasificados.xlsx')

# Mostrar las primeras filas del DataFrame
lista.head()
# Out:
#   tipo de dato       carpeta       ruta                             nombre  \
# 0        watec  Clasificados  Masgrande  Station_1_2019-05-01-00-50-32.avi
# 1        watec  Clasificados  Masgrande  Station_1_2019-05-03-20-53-58.avi
# 2        watec  Clasificados  Masgrande  Station_1_2019-05-06-03-04-03.avi
# 3        watec  Clasificados  Masgrande  Station_1_2019-05-06-19-42-25.avi
# 4        watec  Clasificados  Masgrande  Station_1_2019-05-06-20-45-53.avi
#
#                      nombre con ruta clasificacion bolido inicial  \
# 0  Station_1_2019-05-01-00-50-32.avi                           si
# 1  Station_1_2019-05-03-20-53-58.avi                           si
# 2  Station_1_2019-05-06-03-04-03.avi                           si
# 3  Station_1_2019-05-06-19-42-25.avi                           si
# 4  Station_1_2019-05-06-20-45-53.avi                           si
#
#   clasificacion bolido clasificacion no bolido
# 0                   si                   bolido
# ...

# %%
# Guardar el DataFrame como un archivo CSV
lista.to_csv('/content/sample_data/Watec_Clasificados_DataClasificadosyNoClasificados.csv', index=False)
